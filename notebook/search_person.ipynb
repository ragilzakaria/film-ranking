# %%
keyword = "Tom Holland"
limit = 1000

# %%
from film_ranking.lib.analyze import search_person

# %%
import pandas as pd
# Display all rows and columns
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %%
df = search_person(keyword, limit)
df.head(int(limit))
# Out:
#         nconst                     primaryProfession  primaryName  \
# 0    nm0276169                 actor,writer,director  Tom Holland
# 1    nm0390847  actor,visual_effects,archive_footage  Tom Holland
# 2    nm0390848                    costume_department  Tom Holland
# 3   nm10503517                                 actor  Tom Holland
# 4   nm12059929                                    \N  Tom Holland
# 5   nm13231994                                 actor  Tom Holland
# 6   nm13766308                     camera_department  Tom Holland
# 7    nm2286597            writer,actor,miscellaneous  Tom Holland
# 8    nm2435842                        art_department  Tom Holland
# 9    nm2553723                         miscellaneous  Tom Holland
# 10   nm4042070                                writer  Tom Holland
# 11   nm4043618               actor,producer,director  Tom Holland
# 12   nm4718969                                 actor  Tom Holland
# ...
